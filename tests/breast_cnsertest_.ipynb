# %%
import sys
sys.path.append('..')

from PCA_data_menager import PCADataMenager

# %%
data_frame = PCADataMenager()
data_frame.read_from_csv('datasets/breast+cancer+wisconsin+diagnostic/wdbc.csv', sep=',', header=None)
data_frame.one_hot_encode('1')
data_frame.display()
# Out:
#             0      2      3       4       5        6        7        8  \
# 0      842302  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ...    ...    ...     ...     ...      ...      ...      ...
# 564    926424  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#            9      10  ...      24      25       26       27      28      29  \
# ...

# %%
data_frame.save()

# %%
data_frame.undo()
data_frame.standarize_dataset()
pca_data = data_frame.PCA(2)
pca_data.display()
# Out:
#               pc0          pc1
# 0   -2.952953e+07  1176.590382
# 1   -2.952931e+07  1285.749923
# 2    5.392907e+07   965.498872
# 3    5.397647e+07  -437.551209
# 4    5.398657e+07   900.073782
# ..            ...          ...
# 564 -2.944541e+07  1430.693922
# 565 -2.944515e+07  1061.599517
# 566 -2.944488e+07   331.078486
# 567 -2.944459e+07  1141.436237
# 568 -3.027908e+07  -754.562478
#
# [569 rows x 2 columns]
