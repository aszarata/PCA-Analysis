# %%
import sys
sys.path.append('..')

from app_backend.data_manager import DataManager
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Stage 0

# %% [markdown]
# ## Read from csv

# %%
data_frame = DataManager()
data_frame.read_from_csv('datasets/breast+cancer+wisconsin+diagnostic/wdbc.csv', sep=',', header=None)
data_frame.get_df()
# Out:
#             0  1      2      3       4       5        6        7        8  \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#            9  ...      22     23      24      25       26       27      28  \
# ...

# %% [markdown]
# # Stage 1

# %% [markdown]
# ## Change the variable name

# %%
data_frame.rename_variable('1', 'cancer_type')
data_frame.rename_variable('0', 'ID')
data_frame.get_df()
# Out:
#            ID cancer_type      2      3       4       5        6        7  \
# 0      842302           M  17.99  10.38  122.80  1001.0  0.11840  0.27760
# 1      842517           M  20.57  17.77  132.90  1326.0  0.08474  0.07864
# 2    84300903           M  19.69  21.25  130.00  1203.0  0.10960  0.15990
# 3    84348301           M  11.42  20.38   77.58   386.1  0.14250  0.28390
# 4    84358402           M  20.29  14.34  135.10  1297.0  0.10030  0.13280
# ..        ...         ...    ...    ...     ...     ...      ...      ...
# 564    926424           M  21.56  22.39  142.00  1479.0  0.11100  0.11590
# 565    926682           M  20.13  28.25  131.20  1261.0  0.09780  0.10340
# 566    926954           M  16.60  28.08  108.30   858.1  0.08455  0.10230
# 567    927241           M  20.60  29.33  140.10  1265.0  0.11780  0.27700
# 568     92751           B   7.76  24.54   47.92   181.0  0.05263  0.04362
#
#            8        9  ...      22     23      24      25       26       27  \
# ...

# %% [markdown]
# ## Check the variable type

# %%
data_frame.get_variable_type('cancer_type'), data_frame.get_variable_type('ID')
# Out:
# ('categorical', 'numerical')

# %%
data_frame.get_variable_types()
# Out:
# {'ID': 'numerical',
#  'cancer_type': 'categorical',
#  '2': 'numerical',
#  '3': 'numerical',
#  '4': 'numerical',
#  '5': 'numerical',
#  '6': 'numerical',
#  '7': 'numerical',
#  '8': 'numerical',
#  '9': 'numerical',
#  '10': 'numerical',
#  '11': 'numerical',
#  '12': 'numerical',
#  '13': 'numerical',
#  '14': 'numerical',
#  '15': 'numerical',
#  '16': 'numerical',
#  '17': 'numerical',
#  '18': 'numerical',
#  '19': 'numerical',
#  '20': 'numerical',
#  '21': 'numerical',
#  '22': 'numerical',
#  '23': 'numerical',
#  '24': 'numerical',
#  '25': 'numerical',
#  '26': 'numerical',
#  '27': 'numerical',
#  '28': 'numerical',
#  '29': 'numerical',
#  '30': 'numerical',
#  '31': 'numerical'}

# %% [markdown]
# ## Change the variable type

# %%
data_frame.change_variable_type('2')

# %%
data_frame.get_variable_type('2')
# Out:
# 'categorical'

# %%
data_frame.change_variable_type('2')

# %%
data_frame.get_variable_type('2')
# Out:
# 'numerical'

# %% [markdown]
# ## Undo, Reset

# %% [markdown]
# ### Add useless name

# %%
data_frame.save()
data_frame.rename_variable('2', 'stattatat')
data_frame.get_df()
# Out:
#            ID cancer_type  stattatat      3       4       5        6        7  \
# 0      842302           M      17.99  10.38  122.80  1001.0  0.11840  0.27760
# 1      842517           M      20.57  17.77  132.90  1326.0  0.08474  0.07864
# 2    84300903           M      19.69  21.25  130.00  1203.0  0.10960  0.15990
# 3    84348301           M      11.42  20.38   77.58   386.1  0.14250  0.28390
# 4    84358402           M      20.29  14.34  135.10  1297.0  0.10030  0.13280
# ..        ...         ...        ...    ...     ...     ...      ...      ...
# 564    926424           M      21.56  22.39  142.00  1479.0  0.11100  0.11590
# 565    926682           M      20.13  28.25  131.20  1261.0  0.09780  0.10340
# 566    926954           M      16.60  28.08  108.30   858.1  0.08455  0.10230
# 567    927241           M      20.60  29.33  140.10  1265.0  0.11780  0.27700
# 568     92751           B       7.76  24.54   47.92   181.0  0.05263  0.04362
#
# ...

# %% [markdown]
# ### Reset to last saved changes

# %%
data_frame.undo()
data_frame.get_df()
# Out:
#            ID cancer_type      2      3       4       5        6        7  \
# 0      842302           M  17.99  10.38  122.80  1001.0  0.11840  0.27760
# 1      842517           M  20.57  17.77  132.90  1326.0  0.08474  0.07864
# 2    84300903           M  19.69  21.25  130.00  1203.0  0.10960  0.15990
# 3    84348301           M  11.42  20.38   77.58   386.1  0.14250  0.28390
# 4    84358402           M  20.29  14.34  135.10  1297.0  0.10030  0.13280
# ..        ...         ...    ...    ...     ...     ...      ...      ...
# 564    926424           M  21.56  22.39  142.00  1479.0  0.11100  0.11590
# 565    926682           M  20.13  28.25  131.20  1261.0  0.09780  0.10340
# 566    926954           M  16.60  28.08  108.30   858.1  0.08455  0.10230
# 567    927241           M  20.60  29.33  140.10  1265.0  0.11780  0.27700
# 568     92751           B   7.76  24.54   47.92   181.0  0.05263  0.04362
#
#            8        9  ...      22     23      24      25       26       27  \
# ...

# %% [markdown]
# ### Delete variable

# %%
data_frame.delete_variable('cancer_type')
data_frame.get_df()
# Out:
#            ID      2      3       4       5        6        7        8  \
# 0      842302  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ...    ...    ...     ...     ...      ...      ...      ...
# 564    926424  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#            9      10  ...      22     23      24      25       26       27  \
# ...

# %% [markdown]
# ### Total reset

# %%
data_frame.reset()
data_frame.get_df()
# Out:
#             0  1      2      3       4       5        6        7        8  \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#            9  ...      22     23      24      25       26       27      28  \
# ...

# %% [markdown]
# # Stage 2

# %% [markdown]
# ## Normalize variable

# %%
data_frame.normalize_std('3')
data_frame.get_df()
# Out:
#             0  1      2         3       4       5        6        7        8  \
# 0      842302  M  17.99 -2.071512  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57 -0.353322  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  0.455786  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  0.253509   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29 -1.150804  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...       ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  0.720838  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  2.083301  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  2.043775  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  2.334403  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  1.220718   47.92   181.0  0.05263  0.04362  0.00000
#
# ...

# %%
data_frame.normalize_q('4')
data_frame.get_df()
# Out:
#             0  1      2         3         4       5        6        7  \
# 0      842302  M  17.99 -2.071512  1.646388  1001.0  0.11840  0.27760
# 1      842517  M  20.57 -0.353322  1.995506  1326.0  0.08474  0.07864
# 2    84300903  M  19.69  0.455786  1.895264  1203.0  0.10960  0.15990
# 3    84348301  M  11.42  0.253509  0.083305   386.1  0.14250  0.28390
# 4    84358402  M  20.29 -1.150804  2.071552  1297.0  0.10030  0.13280
# ..        ... ..    ...       ...       ...     ...      ...      ...
# 564    926424  M  21.56  0.720838  2.310059  1479.0  0.11100  0.11590
# 565    926682  M  20.13  2.083301  1.936744  1261.0  0.09780  0.10340
# 566    926954  M  16.60  2.043775  1.145178   858.1  0.08455  0.10230
# 567    927241  M  20.60  2.334403  2.244383  1265.0  0.11780  0.27700
# 568     92751  B   7.76  1.220718 -0.941929   181.0  0.05263  0.04362
#
#            8        9  ...      22     23      24      25       26       27  \
# ...

# %% [markdown]
# ## One-Hot encoding

# %%
data_frame.one_hot_encode('1')
data_frame.get_df()
# Out:
#             0      2         3         4       5        6        7        8  \
# 0      842302  17.99 -2.071512  1.646388  1001.0  0.11840  0.27760  0.30010
# 1      842517  20.57 -0.353322  1.995506  1326.0  0.08474  0.07864  0.08690
# 2    84300903  19.69  0.455786  1.895264  1203.0  0.10960  0.15990  0.19740
# 3    84348301  11.42  0.253509  0.083305   386.1  0.14250  0.28390  0.24140
# 4    84358402  20.29 -1.150804  2.071552  1297.0  0.10030  0.13280  0.19800
# ..        ...    ...       ...       ...     ...      ...      ...      ...
# 564    926424  21.56  0.720838  2.310059  1479.0  0.11100  0.11590  0.24390
# 565    926682  20.13  2.083301  1.936744  1261.0  0.09780  0.10340  0.14400
# 566    926954  16.60  2.043775  1.145178   858.1  0.08455  0.10230  0.09251
# 567    927241  20.60  2.334403  2.244383  1265.0  0.11780  0.27700  0.35140
# 568     92751   7.76  1.220718 -0.941929   181.0  0.05263  0.04362  0.00000
#
# ...

# %%
data_frame.delete_variable('1_B')
data_frame.delete_variable('1_M') # Deleting categorial columns (only for further PCA analysis purposes)
data_frame.save() # save the current state so that there is a possibility to undo

# %% [markdown]
# # Stage 3

# %% [markdown]
# ## PCA analysis

# %% [markdown]
# ### Output for 2 componenst

# %%
data_frame.undo()
data_frame.standarize_dataset()
pca_data2 = data_frame.PCA(15)
pca_data2.get_df()
# Out:
#            pc1        pc2       pc3       pc4       pc5       pc6       pc7  \
# 0     9.175127   1.969538 -1.170595  3.636133 -1.192050 -1.371074  0.371517
# 1     2.381202  -3.750159 -0.579719  1.126447  0.624301 -0.126505 -0.288016
# 2     5.737424  -1.079401 -0.532619  0.902676 -0.180443 -0.401502  0.462780
# 3     7.118121  10.263195 -3.147392  0.121405 -2.965446 -2.559416  1.948463
# 4     3.942225  -1.957967  1.399946  2.934973  0.540377  1.232216 -0.205255
# ..         ...        ...       ...       ...       ...       ...       ...
# 564   6.429671  -3.562224  2.397002  1.196761 -0.071026  2.027005 -1.344012
# 565   3.786127  -3.570277  2.027721 -2.476509 -0.498082 -0.080352 -1.023211
# 566   1.250790  -1.892312  0.533997 -2.075806  1.813233  0.394366 -0.437421
# 567  10.355923   1.694906 -1.905741 -2.349740 -0.028195 -0.656142 -0.195092
# 568  -5.473448  -0.672197  1.475866 -2.283034 -0.176719 -1.570694  0.599813
#
# ...

# %% [markdown]
# ### Graph for 2 components

# %%
plot = pca_data2.plot_2d('pc1', 'pc2')
plot.show()

# %%
plot_var = pca_data2.plot_explained_variance()
plot_var.show()

# %% [markdown]
# ### Output for 3 componenst

# %%
data_frame.undo()
data_frame.standarize_dataset()
pca_data3 = data_frame.PCA(3)
pca_data3.get_df()
# Out:
#            pc1        pc2       pc3
# 0     9.175127   1.969538 -1.170595
# 1     2.381202  -3.750159 -0.579719
# 2     5.737424  -1.079401 -0.532619
# 3     7.118121  10.263195 -3.147392
# 4     3.942225  -1.957967  1.399946
# ..         ...        ...       ...
# 564   6.429671  -3.562224  2.397002
# 565   3.786127  -3.570277  2.027721
# 566   1.250790  -1.892312  0.533997
# 567  10.355923   1.694906 -1.905741
# 568  -5.473448  -0.672197  1.475866
#
# [569 rows x 3 columns]

# %% [markdown]
# # Stage 4

# %% [markdown]
# ## Grouping algorithms

# %%
pca_data2.kmeans_clustering(2)
pca_data2.plot_2d('pc1', 'pc2')
# Out:
# <module 'matplotlib.pyplot' from '/usr/lib/python3/dist-packages/matplotlib/pyplot.py'>

# %%
pca_data2.dbscan_clustering(eps=0.3, min_samples=5)
pca_data2.plot_2d('pc1', 'pc2')
# Out:
# <module 'matplotlib.pyplot' from '/usr/lib/python3/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Group suggestions

# %% [markdown]
# ### k-means

# %%
pca_data2.suggest_clusters_kmeans(15, True)
# Out:
# 2

# %% [markdown]
# ### DBSCAN

# %%
pca_data2.suggest_clusters_dbscan(5, True)
# Out:
# 13.565172472969131
